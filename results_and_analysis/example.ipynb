# %%
from Generate_waveform import predict_waveform_from_sample
import numpy as np
import matplotlib.pyplot as plt

# %%
# x_sample = [m1, m2, λ1, λ2, s1x, s1y, s1z, s2x, s2y, s2z]
x_sample = [[2, 2, 100, 100, 0.2, -0.3, 0.1, 0.1, 0.05, -0.12]]
hp, hc = predict_waveform_from_sample(x_sample)

t1 = np.linspace(0, 2, len(hp))
plt.figure(figsize=(17, 4))
plt.plot(t1, hp)
plt.xlabel(r'$t\ \mathrm{[s]}$')
plt.ylabel('strain')
plt.title("Predicted $h_+$ waveform")
plt.grid(True)
plt.show()
# Out:
# Text(0, 0.5, 'strain')
